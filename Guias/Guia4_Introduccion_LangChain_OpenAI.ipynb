# %% [markdown]
# # Guía 3 — Introducción a LangChain con OpenAI API
# Curso: **IA en el Aula — Nivel Avanzado**
# Profesor: **Luis Daniel Benavides Navarro**
# Fecha: **Octubre 2025**
#
# En esta guía aprenderás los conceptos básicos de **LangChain**, una librería diseñada para construir aplicaciones impulsadas por modelos de lenguaje, integrando la API de OpenAI con flujos más complejos. Exploraremos cómo crear un primer **prompt chain**, administrar memoria y usar herramientas para componer respuestas inteligentes.

# %% [markdown]
# ## 1️⃣ Instalación y configuración inicial
# LangChain se instala como cualquier otra librería de Python. También usaremos `python-dotenv` para gestionar la clave de OpenAI. Ejecute la siguiente celda:

# %%
# %pip install openai langchain python-dotenv langchain-openai
# Out:
# Requirement already satisfied: openai in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.6.1)
# Collecting langchain
#   Downloading langchain-1.0.3-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: python-dotenv in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.2.1)
# Collecting langchain-openai
#   Downloading langchain_openai-1.0.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai) (4.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai) (0.11.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai) (2.12.3)
# Requirement already satisfied: sniffio in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai) (4.15.0)
# Collecting langchain-core<2.0.0,>=1.0.0 (from langchain)
#   Downloading langchain_core-1.0.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting langgraph<1.1.0,>=1.0.2 (from langchain)
#   Downloading langgraph-1.0.2-py3-none-any.whl.metadata (7.4 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Downloading tiktoken-0.12.0-cp311-cp311-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: idna>=2.8 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.0.0->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.0.0->langchain)
#   Downloading langsmith-0.4.38-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (6.0.2)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<2.0.0,>=1.0.0->langchain)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting langgraph-checkpoint<4.0.0,>=2.1.0 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading langgraph_checkpoint-3.0.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.2 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading langgraph_prebuilt-1.0.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting langgraph-sdk<0.3.0,>=0.2.2 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading langgraph_sdk-0.2.9-py3-none-any.whl.metadata (1.5 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading xxhash-3.6.0-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Collecting regex>=2022.1.18 (from tiktoken<1.0.0,>=0.7.0->langchain-openai)
#   Downloading regex-2025.10.23-cp311-cp311-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/41.5 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/41.5 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/41.5 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/41.5 kB ? eta -:--:--
#      ---------------------------- --------- 30.7/41.5 kB 108.9 kB/s eta 0:00:01
#      -------------------------------------  41.0/41.5 kB 140.3 kB/s eta 0:00:01
#      -------------------------------------- 41.5/41.5 kB 125.1 kB/s eta 0:00:00
# Requirement already satisfied: requests>=2.26.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.32.3)
# Requirement already satisfied: colorama in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>4->openai) (0.4.6)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain) (3.0.0)
# Collecting ormsgpack>=1.10.0 (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading ormsgpack-1.11.0-cp311-cp311-win_amd64.whl.metadata (1.2 kB)
# Collecting orjson>=3.10.1 (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading orjson-3.11.4-cp311-cp311-win_amd64.whl.metadata (42 kB)
#      ---------------------------------------- 0.0/42.9 kB ? eta -:--:--
#      ---------------------------------------- 0.0/42.9 kB ? eta -:--:--
#      ---------------------------------------- 0.0/42.9 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/42.9 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/42.9 kB ? eta -:--:--
#      --------------------------- ---------- 30.7/42.9 kB 330.3 kB/s eta 0:00:01
#      ------------------------------------ - 41.0/42.9 kB 219.4 kB/s eta 0:00:01
#      -------------------------------------- 42.9/42.9 kB 191.2 kB/s eta 0:00:00
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain)
#   Downloading zstandard-0.25.0-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.2.3)
# Downloading langchain-1.0.3-py3-none-any.whl (91 kB)
#    ---------------------------------------- 0.0/92.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/92.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/92.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/92.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/92.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/92.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/92.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/92.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/92.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/92.0 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/92.0 kB ? eta -:--:--
#    ------------- -------------------------- 30.7/92.0 kB 325.1 kB/s eta 0:00:01
#    ------------- -------------------------- 30.7/92.0 kB 325.1 kB/s eta 0:00:01
#    ----------------- ---------------------- 41.0/92.0 kB 196.9 kB/s eta 0:00:01
#    -------------------------- ------------- 61.4/92.0 kB 252.2 kB/s eta 0:00:01
#    -------------------------- ------------- 61.4/92.0 kB 252.2 kB/s eta 0:00:01
#    ----------------------------------- ----
#    ---------------------------- ---------- 368.6/506.2 kB 86.9 kB/s eta 0:00:02
#    ----------------------------- --------- 389.1/506.2 kB 90.1 kB/s eta 0:00:02
#    ----------------------------- --------- 389.1/506.2 kB 90.1 kB/s eta 0:00:02
#    ----------------------------- --------- 389.1/506.2 kB 90.1 kB/s eta 0:00:02
#    ------------------------------ -------- 399.4/506.2 kB 89.3 kB/s eta 0:00:02
#    ------------------------------ -------- 399.4/506.2 kB 89.3 kB/s eta 0:00:02
#    -------------------------------- ------ 419.8/506.2 kB 92.0 kB/s eta 0:00:01
#    -------------------------------- ------ 419.8/506.2 kB 92.0 kB/s eta 0:00:01
#    --------------------------------- ----- 440.3/506.2 kB 94.6 kB/s eta 0:00:01
#    --------------------------------- ----- 440.3/506.2 kB 94.6 kB/s eta 0:00:01
#    ---------------------------------- ---- 450.6/506.2 kB 95.2 kB/s eta 0:00:01
#    ---------------------------------- ---- 450.6/506.2 kB 95.2 kB/s eta 0:00:01
#    ------------------------------------ -- 471.0/506.2 kB 98.0 kB/s eta 0:00:01
#    ------------------------------------ -- 471.0/506.2 kB 98.0 kB/s eta 0:00:01
#    ------------------------------------ -- 471.0/506.2 kB 98.0 kB/s eta 0:00:01
#    ------------------------------------ -- 471.0/506.2 kB 98.0 kB/s eta 0:00:01
#    ------------------------------------ -- 471.0/506.2 kB 98.0 kB/s eta 0:00:01
#    ------------------------------------ -- 471.0/506.2 kB 98.0 kB/s eta 0:00:01
#    ------------------------------------ -- 471.0/506.2 kB 98.0 kB/s eta 0:00:01
#    ------------------------------------- - 481.3/506.2 kB 93.3 kB/s eta 0:00:01
#    ------------------------------------- - 481.3/506.2 kB 93.3 kB/s eta 0:00:01
#    --------------------------------------- 506.2/506.2 kB 96.2 kB/s eta 0:00:00
# Installing collected packages: zstandard, xxhash, tenacity, regex, ormsgpack, orjson, jsonpatch, tiktoken, requests-toolbelt, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langchain-openai, langgraph-prebuilt, langgraph, langchain
# Successfully installed jsonpatch-1.33 langchain-1.0.3 langchain-core-1.0.2 langchain-openai-1.0.1 langgraph-1.0.2 langgraph-checkpoint-3.0.0 langgraph-prebuilt-1.0.2 langgraph-sdk-0.2.9 langsmith-0.4.38 orjson-3.11.4 ormsgpack-1.11.0 regex-2025.10.23 requests-toolbelt-1.0.0 tenacity-9.1.2 tiktoken-0.12.0 xxhash-3.6.0 zstandard-0.25.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Users\usuario\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 2️⃣ Cargar variables de entorno y cliente OpenAI
# Crea un archivo `.env` con tu clave de API y cárgala para poder usarla dentro de LangChain. Esto evita exponer tu clave en el código fuente.

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

load_dotenv()  # Cargar archivo .env
api_key = os.getenv("OPENAI_API_KEY")

if not api_key:
    raise ValueError("No se encontró la clave OPENAI_API_KEY en el archivo .env")

# Crear cliente LangChain con OpenAI
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.5)
print("Cliente LangChain con OpenAI inicializado correctamente.")
# Out:
# Cliente LangChain con OpenAI inicializado correctamente.

# %% [markdown]
# ## 3️⃣ Primer ejemplo: Prompt simple con LangChain
# LangChain utiliza **chains** (cadenas de pasos) para procesar información. Comencemos con una cadena simple que envía un mensaje al modelo y obtiene la respuesta.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# Initialize the LLM (uses your OpenAI API key from environment)
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.5)

# Create a simple prompt
prompt = ChatPromptTemplate.from_template(
    "Explica en dos frases el concepto de {tema}."
)

# Combine the components using LCEL (LangChain Expression Language)
chain = prompt | llm | StrOutputParser()

# Run it
result = chain.invoke({"tema": "aprendizaje automático"})
print(result)
# Out:
# El aprendizaje automático es una rama de la inteligencia artificial que permite a las computadoras aprender de datos y mejorar su rendimiento en tareas específicas sin ser programadas explícitamente para cada una. Utiliza algoritmos y modelos estadísticos para identificar patrones y hacer predicciones basadas en la información proporcionada.

# %% [markdown]
# ### Explicación
# - **ChatPromptTemplate:** define la estructura del mensaje que se envía al modelo.
# - **ChatOpenAI:** la conexión real al modelo.
# - **chain** crea la cadena de componentes usando LCEL (LangChain Expression Language).
# - **StrOutputParser** convierte la salida estructurada del modelo en texto plano.
# - **chain.invoke:** ejecuta la cadena pasando los valores del prompt.
#
# Este patrón permite reutilizar prompts para distintos temas o contextos.

# %% [markdown]
# ## 4️⃣ Ejemplo 2: Encadenar múltiples pasos
# LangChain permite combinar varios pasos en una misma ejecución. En este ejemplo, crearemos dos prompts: uno para definir un tema y otro para generar una aplicación educativa basada en el resultado.

# %%
from langchain.chains import SimpleSequentialChain

# Primer paso: obtener una descripción
primer_prompt = PromptTemplate(
    input_variables=["tema"],
    template="Explica brevemente el concepto de {tema}."
)
primer_chain = LLMChain(llm=llm, prompt=primer_prompt)

# Segundo paso: generar aplicación educativa
segundo_prompt = PromptTemplate(
    input_variables=["concepto"],
    template="Propón una aplicación educativa del siguiente concepto: {concepto}."
)
segundo_chain = LLMChain(llm=llm, prompt=segundo_prompt)

# Combinar ambos pasos en una cadena secuencial
chain_secuencial = SimpleSequentialChain(chains=[primer_chain, segundo_chain])

# Ejecutar la cadena completa
resultado = chain_secuencial.run("realidad aumentada")
print(resultado)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from langchain.chains import SimpleSequentialChain
#       3 # Primer paso: obtener una descripción
#       4 primer_prompt = PromptTemplate(
#       5     input_variables=["tema"],
#       6     template="Explica brevemente el concepto de {tema}."
#       7 )
#
# ModuleNotFoundError: No module named 'langchain.chains'

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from operator import itemgetter

# 1) LLM (usa tu OPENAI_API_KEY en el entorno)
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.5)
to_str = StrOutputParser()

# 2) Paso 1: explicar brevemente el concepto de {tema}
primer_prompt = ChatPromptTemplate.from_template(
    "Explica brevemente el concepto de {tema}."
)
primer_paso = primer_prompt | llm | to_str
# `primer_paso` produce un string, por ejemplo: "La realidad aumentada es ..."

# 3) Paso 2: proponer una aplicación educativa usando la salida del paso 1 como {concepto}
segundo_prompt = ChatPromptTemplate.from_template(
    "Propón una aplicación educativa del siguiente concepto: {concepto}."
)
segundo_paso = segundo_prompt | llm | to_str

# 4) Encadenar: mapear la entrada {tema} al primer paso, y su salida a {concepto} del segundo
cadena_secuencial = {"concepto": primer_paso} | segundo_paso

# 5) Ejecutar la cadena completa
resultado = cadena_secuencial.invoke({"tema": "realidad aumentada"})
print(resultado)
# Out:
# **Aplicación Educativa: "ExplorAR: Aventura de Aprendizaje en Realidad Aumentada"**
#
# **Descripción General:**
# ExplorAR es una aplicación educativa que utiliza la realidad aumentada para enriquecer el aprendizaje de los estudiantes en diversas materias como ciencias, historia, geografía y arte. A través de la app, los estudiantes pueden escanear objetos del mundo real, como libros, mapas o instalaciones educativas, y acceder a contenido digital interactivo que complementa y expande su comprensión de los temas estudiados.
#
# **Características de la Aplicación:**
#
# 1. **Contenido Interactivo:**
#    - Al escanear un libro de texto, los estudiantes pueden ver videos explicativos, gráficos animados y modelos 3D que ilustran conceptos complejos.
#    - En materias de ciencias, pueden observar reacciones químicas en 3D o explorar el sistema solar con planetas que giran y se mueven en su entorno.
#
# 2. **Exploraciones Históricas:**
#    - Los estudiantes pueden apuntar su dispositivo hacia un lugar histórico o una imagen de un evento y ver una recreación de la escena, con personajes interactivos que cuentan la historia desde diferentes perspectivas.
#    - Se pueden incluir líneas de tiempo interactivas que los estudiantes pueden explorar al tocar diferentes elementos.
#
# 3. **Geografía Interactiva:**
#    - Al escanear un mapa, los estudiantes pueden ver información adicional sobre los países, como datos demográficos, cultura y geografía física, así como imágenes y videos de esos lugares.
#    - Se pueden realizar actividades de "misiones" donde los estudiantes deben encontrar y escanear diferentes puntos de interés en su entorno para completar un recorrido educativo.
#
# 4. **Arte y Cultura:**
#    - Al escanear obras de arte, los estudiantes pueden obtener información sobre el artista, el contexto histórico y el significado de la obra, así como ver la obra en diferentes estilos o épocas.
#    - La aplicación puede incluir actividades creativas donde los estudiantes pueden crear su propia obra de arte digital utilizando herramientas de RA.
#
# 5. **Gamificación:**
#    - La aplicación puede incluir desafíos y juegos educativos que motiven a los estudiantes a interactuar con el contenido, acumulando puntos o recompensas por completar tareas y responder preguntas correctamente.
#    - Los estudiantes pueden trabajar en equipos para resolver problemas o completar misiones, fomentando la colaboración.
#
# 6. **Accesibilidad y Personalización:**
#    - Los educadores pueden personalizar el contenido de la aplicación para adaptarse a las necesidades específicas de sus clases y niveles de aprendizaje.
#    - La aplicación puede ofrecer diferentes niveles de dificultad y opciones de accesibilidad para estudiantes con discapacidades.
#
# **Beneficios de "ExplorAR":**
# - Fomenta un aprendizaje activo y participativo, donde los estudiantes son protagonistas de su proceso educativo.
# - Facilita la comprensión de conceptos abstractos mediante la visualización y la interacción.
# - Promueve la curiosidad y el interés por el aprendizaje al hacer que el contenido sea más atractivo y relevante.
# - Aumenta la retención de información a través de experiencias inmersivas y contextualizadas.
#
# **Conclusión:**
# ExplorAR no solo transforma la manera en que los estudiantes interactúan con el contenido educativo, sino que también prepara a las nuevas generaciones para un mundo cada vez más digital y tecnológico, equipándolos con habilidades críticas para el futuro.

# %% [markdown]
# ### Explicación
# - **cadena_secuencial:** permite conectar varias cadenas; la salida de una se convierte en la entrada de la siguiente.
# - En este caso, el modelo primero explica el tema y luego sugiere una aplicación educativa.
#
# Este tipo de flujo es ideal para generar contenido didáctico o ideas para proyectos en clase.

# %% [markdown]
# ## 5️⃣ Ejemplo 3: Añadir memoria a la conversación
# LangChain incluye módulos de **memoria** para mantener contexto entre múltiples interacciones. Esto permite simular conversaciones educativas más naturales, donde el modelo recuerda temas previos.

# %%
# Instalar si hace falta:
# %pip install -U langchain langchain-openai

from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.messages import HumanMessage, AIMessage
from langchain_core.output_parsers import StrOutputParser

# LLM (requiere OPENAI_API_KEY en el entorno)
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.5)
to_str = StrOutputParser()

# Prompt con hueco para el historial
prompt = ChatPromptTemplate.from_messages([
    ("system", "Eres un asistente educativo claro y conciso."),
    MessagesPlaceholder("chat_history"),      # ← aquí va la memoria
    ("human", "{input}")
])

# Cadena base
chain = prompt | llm | to_str

# Memoria simple como lista de mensajes
history: list = []

def chat(user_text: str) -> str:
    """
    Envía un turno del usuario, usa el historial y actualiza la memoria
    con el par (usuario, asistente).
    """
    global history
    # Ejecutar la cadena inyectando el historial actual
    answer = chain.invoke({"input": user_text, "chat_history": history})
    # Actualizar memoria (guardar los dos mensajes)
    history += [HumanMessage(content=user_text), AIMessage(content=answer)]
    return answer

# --- Ejemplo de uso (tres turnos) ---
print(chat("Hola, soy un profesor de informática."))
print(chat("¿Puedes explicarme cómo introducir IA a mis estudiantes?"))
print(chat("¿Qué ejemplos prácticos puedo usar en la clase?"))
# Out:
# ¡Hola! Encantado de ayudarte. ¿En qué aspecto de la informática necesitas asistencia?
# Claro, aquí tienes algunas sugerencias para introducir la inteligencia artificial (IA) a tus estudiantes:
#
# 1. **Conceptos Básicos**:
#    - Comienza explicando qué es la IA y sus aplicaciones en la vida cotidiana (asistentes virtuales, recomendaciones de productos, etc.).
#    - Introduce términos clave como aprendizaje automático, redes neuronales y procesamiento de lenguaje natural.
#
# 2. **Ejemplos Prácticos**:
#    - Muestra ejemplos de IA en acción, como chatbots, reconocimiento de voz o sistemas de recomendación.
#    - Puedes usar aplicaciones o herramientas accesibles que demuestren IA, como Google Assistant o IBM Watson.
#
# 3. **Proyectos Sencillos**:
#    - Propón proyectos simples, como crear un chatbot básico utilizando plataformas como Scratch o herramientas de programación visual.
#    - Utiliza herramientas como Teachable Machine de Google para que los estudiantes experimenten con modelos de aprendizaje automático.
#
# 4. **Ética y Responsabilidad**:
#    - Discute las implicaciones éticas de la IA, incluyendo sesgos, privacidad y el impacto en el empleo.
#    - Fomenta el pensamiento crítico sobre el uso responsable de la tecnología.
#
# 5. **Recursos y Herramientas**:
#    - Proporciona recursos en línea, como cursos gratuitos de plataformas como Coursera o edX.
#    - Recomienda libros o artículos accesibles sobre IA.
#
# 6. **Invitados Especiales**:
#    - Considera invitar a profesionales del campo de la IA para que compartan su experiencia y conocimientos.
#
# 7. **Fomentar la Curiosidad**:
#    - Anima a los estudiantes a investigar sobre IA y sus aplicaciones en áreas que les interesen, como la salud, el arte o los videojuegos.
#
# Recuerda adaptar el contenido según el nivel de tus estudiantes y sus intereses. ¡Buena suerte!
# Aquí tienes algunos ejemplos prácticos de IA que puedes utilizar en clase:
#
# 1. **Chatbots**:
#    - Crea un chatbot simple usando plataformas como Chatbot.com o Botsify. Los estudiantes pueden interactuar con él y aprender sobre procesamiento de lenguaje natural.
#
# 2. **Teachable Machine**:
#    - Utiliza Google Teachable Machine para que los estudiantes creen modelos de reconocimiento de imágenes, sonidos o poses. Es una forma divertida de aprender sobre aprendizaje automático.
#
# 3. **Reconocimiento de Voz**:
#    - Usa herramientas como Google Speech Recognition para que los estudiantes experimenten con el reconocimiento de voz. Pueden crear una pequeña aplicación que convierta voz a texto.
#
# 4. **Juegos de IA**:
#    - Introduce juegos que utilizan IA, como "Akinator" (un juego de adivinanza) o "Google Quick, Draw!" (donde la IA intenta adivinar lo que dibujas). Analiza cómo funciona la IA detrás de estos juegos.
#
# 5. **Análisis de Sentimientos**:
#    - Muestra cómo se puede analizar el sentimiento en textos usando herramientas como MonkeyLearn. Los estudiantes pueden analizar tweets o reseñas de productos.
#
# 6. **Visión por Computadora**:
#    - Utiliza plataformas como OpenCV para mostrar cómo se puede detectar objetos en imágenes o videos. Puedes hacer demostraciones simples de detección de caras.
#
# 7. **Proyectos de Programación**:
#    - Si tus estudiantes tienen conocimientos de programación, puedes guiarlos para que creen un proyecto de IA simple en Python usando bibliotecas como TensorFlow o scikit-learn.
#
# 8. **Simulaciones de IA**:
#    - Usa simuladores en línea que muestran cómo funcionan los algoritmos de IA, como simulaciones de redes neuronales o algoritmos de aprendizaje por refuerzo.
#
# 9. **Aplicaciones de Recomendación**:
#    - Analiza cómo funcionan los sistemas de recomendación (como los de Netflix o Amazon) y permite que los estudiantes creen su propio sistema de recomendaciones básico.
#
# 10. **Proyectos de Arte Generativo**:
#     - Introduce a los estudiantes al arte generativo utilizando IA, como DALL-E o DeepArt. Pueden experimentar creando obras de arte a partir de descripciones textuales.
#
# Estos ejemplos son interactivos y fomentan la participación activa de los estudiantes, lo que puede hacer que el aprendizaje sobre IA sea más atractivo y significativo.

# %% [markdown]
# ### Explicación
# - **ConversationBufferMemory:** almacena los mensajes anteriores en la conversación.
# - **ConversationChain:** combina el modelo con la memoria.
# - Esta funcionalidad es útil para tutores inteligentes o chatbots educativos que requieren continuidad en el diálogo.

# %% [markdown]
# ## 6️⃣ Buenas prácticas con LangChain + OpenAI
# - Usa prompts **claros y estructurados**: el modelo responde mejor cuando la tarea está bien definida.
# - Controla `temperature` según la tarea: bajo (0.1–0.3) para precisión, alto (0.7–0.9) para creatividad.
# - Guarda logs o historiales si tu aplicación incluye interacción prolongada.
# - Limita la longitud de las respuestas con `max_tokens` para evitar costos o respuestas excesivas.
# - Documenta tus cadenas (`LLMChain`) para reusarlas en distintos contextos educativos.

# %% [markdown]
# ## ✅ Conclusión
# Has aprendido los fundamentos de LangChain: prompts, chains, memoria y flujo secuencial. Estos conceptos son la base para desarrollar asistentes educativos, tutores personalizados o sistemas de generación de contenido en el aula. En la próxima guía implementaremos un **asistente educativo con RAG (Retrieval-Augmented Generation)** usando tus propios materiales docentes.
